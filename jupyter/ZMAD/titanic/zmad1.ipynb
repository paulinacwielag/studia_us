# %% [markdown]
# https://github.com/gedeck/practical-statistics-for-data-scientists
#
#
# https://github.com/DataRepo2019/Data-files
#
# https://github.com/thomas-haslwanter/statsintro_python/tree/master/ISP

# %%
import pandas as pd
import numpy as np

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
import seaborn as sns

# %%
x = np.random.randn(500)

# %%
plt.plot(x, '.')
plt.show()

# %%
plt.scatter(x,x)

# %%
plt.hist(x, bins=25)
# Out:
# (array([ 2.,  1.,  0.,  2.,  1.,  5.,  9.,  8., 20., 23., 24., 40., 41.,
#         48., 41., 49., 39., 34., 46., 30., 14.,  8., 10.,  2.,  3.]),
#  array([-3.3604701 , -3.13109188, -2.90171365, -2.67233543, -2.44295721,
#         -2.21357898, -1.98420076, -1.75482253, -1.52544431, -1.29606609,
#         -1.06668786, -0.83730964, -0.60793142, -0.37855319, -0.14917497,
#          0.08020326,  0.30958148,  0.5389597 ,  0.76833793,  0.99771615,
#          1.22709437,  1.4564726 ,  1.68585082,  1.91522905,  2.14460727,
#          2.37398549]),
#  <BarContainer object of 25 artists>)

# %%
sns.kdeplot(x)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.plot(stats.cumfreq(x,10)[0])

# %%
plt.boxplot(x, sym='*')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fbaeacef730>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fbaeacefdf0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fbaeacef3d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fbaeacff4f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fbaeacff880>],
#  'means': []}

# %%
index = np.arange(5)
y = index**2
errorBar = index/2 
plt.errorbar(index,y, yerr=errorBar, fmt='o',capsize=5, capthick=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
nd = stats.norm
data = nd.rvs(size=(100))
nd2 = stats.norm(loc = 3, scale = 1.5)
data2 = nd2.rvs(size=(100))

# %%
df = pd.DataFrame({'Girls':data, 'Boys':data2})
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(data=df)
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(10, 4),
columns=['a', 'b', 'c', 'd'])
df.plot(kind='bar', grid=False)
# Out:
# <AxesSubplot:>

# %%
txtLabels = 'Cats', 'Dogs', 'Frogs', 'Others'
fractions = [45, 30, 15, 10]
offsets =(0, 0.05, 0, 0)
plt.pie(fractions, explode=offsets, labels=txtLabels,
autopct='%1.1f%%', shadow=True, startangle=90,
colors=sns.color_palette('muted') )
plt.axis('equal')
# Out:
# (-1.1276423510427096,
#  1.1321050521541118,
#  -1.1554662242543934,
#  1.1026412539202821)

# %%
df2 = pd.DataFrame(np.random.rand(50, 4),
columns=['a', 'b', 'c', 'd'])
df2.plot(kind='scatter', x='a', y='b', s=df2['c']*300);

# %% [markdown]
# ===========================================
#
# 3D

# %%
tyt=pd.read_csv("titanic.csv")

# %%
tyt
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import numpy as np
from matplotlib import cm
from mpl_toolkits.mplot3d.axes3d import get_test_data

# %%
fig = plt.figure(figsize=plt.figaspect(0.3))
ax = fig.add_subplot(1, 2, 1, projection='3d')
# Generate the grid
X = np.arange(-5, 5, 0.1)
Y = np.arange(-5, 5, 0.1)
X, Y = np.meshgrid(X, Y)
# Generate the surface data
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
cmap=cm.GnBu, linewidth=0, antialiased=False)
ax.set_zlim3d(-1.01, 1.01)
fig.colorbar(surf, shrink=0.5, aspect=10)
#---- Second subplot
ax = fig.add_subplot(1, 2, 2, projection='3d')
X, Y, Z = get_test_data(0.05)
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)
#outfile = '3dGraph.png'
#plt.savefig(outfile, dpi=200)
plt.show()

# %% [markdown]
# =================================
#
# **group by**
#
# Split a pandas object into pieces using one or more keys (in the form of func‐
# tions, arrays, or DataFrame column names)
#
# Calculate group summary statistics, like count, mean, or standard deviation, or a
# user-defined function
#
# Apply within-group transformations or other manipulations, like normalization,
# linear regression, rank, or subset selection
#
# Compute pivot tables and cross-tabulations
#
# Perform quantile analysis and other statistical group analyses

# %%
df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
'key2' : ['one', 'two', 'one', 'two', 'one'],
'data1' : np.random.randn(5),
'data2' : np.random.randn(5)})

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.840940  0.188342
# 1    a  two -0.502202  0.171571
# 2    b  one  1.183261  0.541848
# 3    b  two -1.160140  0.147806
# 4    a  one -2.199480 -0.617557

# %%
grouped = df['data1'].groupby(df['key1'])

# %%
grouped

# %%
grouped.mean()
# Out:
# key1
# a   -0.620247
# b    0.011560
# Name: data1, dtype: float64

# %%
means = df['data1'].groupby([df['key1'], df['key2']]).mean()

# %%
means
# Out:
# key1  key2
# a     one    -0.679270
#       two    -0.502202
# b     one     1.183261
#       two    -1.160140
# Name: data1, dtype: float64

# %%
means.unstack()
# Out:
# key2       one       two
# key1
# a    -0.679270 -0.502202
# b     1.183261 -1.160140

# %%
states = np.array(['Ohio', 'California', 'California', 'Ohio', 'Ohio'])
years = np.array([2005, 2005, 2006, 2005, 2006])

# %%
df['data1'].groupby([states, years]).mean()
# Out:
# California  2005   -0.502202
#             2006    1.183261
# Ohio        2005   -0.159600
#             2006   -2.199480
# Name: data1, dtype: float64

# %%
df.groupby(['key1', 'key2']).size()
# Out:
# key1  key2
# a     one     2
#       two     1
# b     one     1
#       two     1
# dtype: int64

# %%
people = pd.DataFrame(np.random.randn(5, 5),columns=['a', 'b', 'c', 'd', 'e'],index=['Joe', 'Steve', 'Wes', 'Jim', 'Travis'])

# %%
people.iloc[2:3, [1, 2]] = np.nan

# %%
mapping = {'a': 'red', 'b': 'red', 'c': 'blue','d': 'blue', 'e': 'red', 'f' : 'orange'}

# %%
by_column = people.groupby(mapping, axis=1)

# %%
people
# Out:
#                a         b         c         d         e
# Joe    -0.163696  0.509890 -0.857351 -0.712501  0.944446
# Steve   0.262158 -0.359122 -1.205603 -0.222862 -0.433770
# Wes    -1.113391       NaN       NaN -0.284951 -1.438286
# Jim    -0.930448  0.400923  0.627763  0.850505  0.440712
# Travis -0.697105  1.682951  0.063781 -1.409856  0.177874

# %%
by_column.sum()
# Out:
#             blue       red
# Joe    -1.569851  1.290640
# Steve  -1.428466 -0.530734
# Wes    -0.284951 -2.551677
# Jim     1.478268 -0.088813
# Travis -1.346074  1.163719

# %%
people.groupby(len).sum()
# Out:
#           a         b         c         d         e
# 3 -2.207535  0.910812 -0.229587 -0.146947 -0.053127
# 5  0.262158 -0.359122 -1.205603 -0.222862 -0.433770
# 6 -0.697105  1.682951  0.063781 -1.409856  0.177874

# %% [markdown]
# **Agregacja**
#
# count
#
# sum
#
# mean
#
# median
#
# std, var
#
# min, max
#
# prod
#
# first, last

# %%
(df['data1']).min()
# Out:
# -2.199479754153898

# %%
tips = pd.read_csv('tips.csv')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pct'] = tips['tip'] / tips['total_bill']

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808

# %%
grouped = tips.groupby(['day', 'smoker'])

# %%
grouped_pct = grouped['tip_pct']

# %%
grouped_pct.describe()
# Out:
#              count      mean       std       min       25%       50%  \
# day  smoker
# Fri  No        4.0  0.151650  0.028123  0.120385  0.137239  0.149241
#      Yes      15.0  0.174783  0.051293  0.103555  0.133739  0.173913
# Sat  No       45.0  0.158048  0.039767  0.056797  0.136240  0.150152
#      Yes      42.0  0.147906  0.061375  0.035638  0.091797  0.153624
# Sun  No       57.0  0.160113  0.042347  0.059447  0.139780  0.161665
#      Yes      19.0  0.187250  0.154134  0.065660  0.097723  0.138122
# Thur No       45.0  0.160298  0.038774  0.072961  0.137741  0.153492
#      Yes      17.0  0.163863  0.039389  0.090014  0.148038  0.153846
#
#                   75%       max
# day  smoker
# Fri  No      0.163652  0.187735
#      Yes     0.209240  0.263480
# Sat  No      0.183915  0.291990
#      Yes     0.190502  0.325733
# Sun  No      0.185185  0.252672
#      Yes     0.215325  0.710345
# Thur No      0.184843  0.266312
#      Yes     0.194837  0.241255

# %%
grouped_pct.agg('mean')
# Out:
# day   smoker
# Fri   No        0.151650
#       Yes       0.174783
# Sat   No        0.158048
#       Yes       0.147906
# Sun   No        0.160113
#       Yes       0.187250
# Thur  No        0.160298
#       Yes       0.163863
# Name: tip_pct, dtype: float64

# %%
functions = ['count', 'mean', 'max']
result = grouped['tip_pct', 'total_bill'].agg(functions)
result
# Out:
# /tmp/ipykernel_1133871/576261660.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   result = grouped['tip_pct', 'total_bill'].agg(functions)
#             tip_pct                     total_bill
#               count      mean       max      count       mean    max
# day  smoker
# Fri  No           4  0.151650  0.187735          4  18.420000  22.75
#      Yes         15  0.174783  0.263480         15  16.813333  40.17
# Sat  No          45  0.158048  0.291990         45  19.661778  48.33
#      Yes         42  0.147906  0.325733         42  21.276667  50.81
# Sun  No          57  0.160113  0.252672         57  20.506667  48.17
#      Yes         19  0.187250  0.710345         19  24.120000  45.35
# Thur No          45  0.160298  0.266312         45  17.113111  41.19
#      Yes         17  0.163863  0.241255         17  19.190588  43.11

# %%
result['tip_pct']
# Out:
#              count      mean       max
# day  smoker
# Fri  No          4  0.151650  0.187735
#      Yes        15  0.174783  0.263480
# Sat  No         45  0.158048  0.291990
#      Yes        42  0.147906  0.325733
# Sun  No         57  0.160113  0.252672
#      Yes        19  0.187250  0.710345
# Thur No         45  0.160298  0.266312
#      Yes        17  0.163863  0.241255

# %%
pd.read

# %%
# zad.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


titanic = pd.read_csv (r'titanic.csv')
print (titanic)

sns.boxplot(x='Age', y='Sex', data=titanic)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.Age.mean() # średnia
# Out:
# 29.69911764705882

# %%
ramka=titanic.groupby("Sex")
print(ramka)

# %%
kobiety=ramka.get_group("female")

#kobiety
kobiety.Age.mean()
# Out:
# 27.915708812260537

# %%
mezczyzni=ramka.get_group("male")

#mezczyzni
mezczyzni.Age.mean()
# Out:
# 30.72664459161148

# %%
import scipy
from scipy.stats import shapiro
shapiro(kobiety['Age'])
# Out:
# ShapiroResult(statistic=nan, pvalue=1.0)

# %%
import scipy
from scipy.stats import shapiro
shapiro(mezczyzni['Age'])
# Out:
# ShapiroResult(statistic=nan, pvalue=1.0)

# %%
import numpy as np

titanic = np.array(titanic["Age"][titanic["Sex"] == "male"])
titanic = titanic[~np.isnan(titanic)]

# %%
stats.shapiro(titanic)
# Out:
# ShapiroResult(statistic=0.9747278094291687, pvalue=4.571295733057923e-07)

# %%
# od Marka

import numpy as np

male_age = np.array(titanic["Age"][titanic["Sex"] == "male"])
female_age = np.array(titanic["Age"][titanic["Sex"] == "female"])
male_age = male_age[~np.isnan(male_age)]
female_age = female_age[~np.isnan(female_age)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1137364/3540260361.py in <module>
#       1 import numpy as np
#       2
# ----> 3 male_age = np.array(titanic["Age"][titanic["Sex"] == "male"])
#       4 female_age = np.array(titanic["Age"][titanic["Sex"] == "female"])
#       5 male_age = male_age[~np.isnan(male_age)]
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
