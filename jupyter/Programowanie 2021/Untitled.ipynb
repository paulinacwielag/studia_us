# %%
rdzenie_p = {'weso': 1,
            'szczęś': 1,
            'dobr': 1,
            'uśmiech': 1,
            'wygod': 1,
            'kreatywn': 1,
            'lojaln': 1,
            'entuzja': 1,
            'podekscytowan': 1,
            'ekscytacj': 1,
            'przyja': 1,
            'pracowit': 1,
            'życzliw': 1,
            'zmotywowa': 1,
            'optymist': 1,
            'towarzy': 1,
            'pozytywn': 1,
            'piękn': 2,
            'faj': 1,
            'baj': 1,
            'apety': 1,
            'błog': 2,
            'cudown': 2,
            'doskona': 3,
            'fantastyczn': 3,
            'mił': 1,
            'przyjemn': 1,
            'rewelac': 3,
            'sympat': 1,
            'smaczn': 1,
            'super': 1,
            'świetn': 2,
            'szałow': 2,
            'wyśmienit': 3,
            'zjawiskow': 3,
            'romanty': 1,
            'radoś': 1, # radość, radości
            'radosny': 1,
            'radosna': 1,
            'radosne': 1, # wykluczenie imienia "Radosław"
            'rozrywk': 1,
            'atrakcyjn': 2,
            'ciekaw': 1,
            'ciepłe': 1,
            'ciepły': 1,
            'ciepła': 1, # wykluczenie słów takich jak np. "ciepłownia" 
            'cierpliw': 1,
            'przystoj': 2,
            'ładn': 1,
            'aktyw': 1,
            'anielsk': 2,
            'entuzja': 1,
            'mądr': 1,
            'pomoc': 1,
            'lepiej': 2, # wykluczenie słów takich jak np. "lepianka"
            'lepsz': 2,
            'weselszy': 2,
            'milszy': 2, # bo zmienia się budowa zdania wesoły : weselsze
            'niesamowi': 3,
            'dobrobyt': 2}

# %%
rdzenie_n = {'przeraż': 3,
            'brzyd': 2,
            'śmier': 3,
            'stra': 2,
            'agres': 3,
            'negatywn': 1,
            'ocięża': 1,
            'niemożli': 1,
            'wściekł': 2,
            'nienawi': 3,
            'aroganc': 1,
            'beznadziej': 3,
            'bied': 1,
            'brutaln': 3,
            'zimn': 1,
            'diab': 2,
            'zła': 1,
            'zły': 1,
            'zło': 1,
            'złe': 1, # za krótki rdzeń, dużo wyrazów z nim
            'szkod': 1,
            'przykr': 1,
            'podejrzliw': 1,
            'załaman': 2,
            'buntow': 1,
            'wrog': 1,
            'podł': 2,
            'obraż': 1,
            'obraź': 1,
            'odmow': 1,
            'samot': 1,
            'koszmar': 2,
            'pogard': 2,
            'sceptyczny': 1,
            'zgub': 1,
            'destrukcj': 2,
            'nikczemn': 2,
            'niecny': 2,
            'irytując': 1,
            'zirytowa': 1,
            'rozczarowa': 1,
            'smut': 1,
            'znudz': 1,
            'zrani': 1,
            'gniew': 2,
            'uraż': 1,
            'przygnęb': 1,
            'depres': 2,
            'panik': 2,
            'spanikowan': 2,
            'upokorz': 1,
            'wyczerpan': 1,
            'podlejszy': 2,
            'gorszy': 2,
            'zazdro': 1}

# %%
rdzenie_neut = ['zwykł', 'zwykl', 'zwyczaj', 'star', 'młod', 'wysok', 'nisk', 'dług', 'krótk', 'szerok', 'wąsk', 'grub', 'chud', 'mał', 'duż', 'śred', 'szybk', 'woln', 'męsk', 'chłopięc', 'dziewczęc', 'dziecięc', 'żeńsk', 'dam', 'moc', 'pust', 'prost', 'gładk', 'szorstk', 'słodk', 'dźwię', 'tward', 'miękk', 'kolorow', 'natura', 'ambiwalentn', 'typow', 'bogat', 'bogacz', 'przystos', 'przylega', 'przyzwoit', 'domow', 'pospolit', 'udokumentowa', 'nagra', 'opis', 'zapis', 'przeczyta', 'obejrz', 'wysłucha', 'codzienn']

# %%
rdzenie_niejed = ['nigdy', 'zawsze', 'czasami', 'wcale', 'często', 'zazwyczaj', 'rzadko', 'niekiedy', 'stanowcz', 'odpowiedni', 'solid', 'śwież', 'wystarczając', 'szal', 'szał', 'wybitn', 'osłupieni', 'zdziw', 'oszołomi', 'zdumion', 'zdumiewając', 'zaskocz', 'burzliw', 'pogod', 'nie mógł się doczekać', 'nie mogła się doczekać', 'nie mogli się doczekać', 'ciemn', 'para', 'zabi', 'jasn', 'emocj', 'granat', 'sensacj', 'asymil', 'chęć', 'zamarz', 'pokój', 'próba', 'strzel', 'skończ', 'zakończ', 'niecodzienn', 'szok', 'prawd', 'celow', 'pozby', 'upi', 'uprawia', 'dawać', 'doprowadz', 'gra', 'gryźć', 'gryz', 'podda', 'kopa', 'kręci', 'drąży', 'legną', 'martw']
