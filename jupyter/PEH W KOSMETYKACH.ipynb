# %%
def peh(L):
    proteiny = ['kos', 'helikopter']
    humektanty = ['pies', 'kot']
    emolienty = ['trawa', 'laptop']
    
    pro_w_kos = []
    hum_w_kos = []
    emo_w_kos = []
    
    for skladnik in L:
        if skladnik in proteiny:
            pro_w_kos.append(skladnik)
        if skladnik in humektanty:
            hum_w_kos.append(skladnik)
        if skladnik in emolienty:
            emo_w_kos.append(skladnik)
    
    return f'W kosmetyku jest: {len(pro_w_kos)} protein, {len(hum_w_kos)} humektantów, {len(emo_w_kos)} emolientów.'

# %%
peh([laptop, trawa])
# Out:
# 'W kosmetyku jest: 0 protein, 0 humektantów, 2 emolientów.'

# %%
kosmetyk = input(str('Wpisz nazwę kosmetyku: '))
sklad = input(str('Wpisz jego skład: '))

lista_sklad = sklad.split(', ')

print(lista_sklad)

proteiny = ['kos', 'helikopter']
humektanty = ['pies', 'kot']
emolienty = ['trawa', 'laptop']

for element in lista_sklad:
    pro_w_kos = []
    hum_w_kos = []
    emo_w_kos = []
    
    for skladnik in lista_sklad:
        if skladnik in proteiny:
            pro_w_kos.append(skladnik)
        if skladnik in humektanty:
            hum_w_kos.append(skladnik)
        if skladnik in emolienty:
            emo_w_kos.append(skladnik)
            
    

print(f'W kosmetyku {kosmetyk} jest: {len(pro_w_kos)} protein, {len(hum_w_kos)} humektantów, {len(emo_w_kos)} emolientów. Kolejność ich występowania: ')
# Out:
# Wpisz nazwę kosmetyku: on
# Wpisz jego skład: kos, gag
# ['kos', 'gag']
# W kosmetyku on jest: 1 protein, 0 humektantów, 0 emolientów. Kolejność ich występowania:

# %%
kosmetyk = input(str('Wpisz nazwę kosmetyku: '))
sklad = input(str('Wpisz jego skład: '))

lista_sklad = sklad.split(', ')

proteiny = ['kos', 'helikopter']
humektanty = ['pies', 'kot']
emolienty = ['trawa', 'laptop']

for element in lista_sklad:
    pro_w_kos = []
    hum_w_kos = []
    emo_w_kos = []
    
    for skladnik in lista_sklad:
        if skladnik in proteiny:
            pro_w_kos.append(skladnik)
        if skladnik in humektanty:
            hum_w_kos.append(skladnik)
        if skladnik in emolienty:
            emo_w_kos.append(skladnik)
            
for kolejnosc, skladnik in enumerate(lista_sklad):
    if skladnik in proteiny:
        print(kolejnosc + 1, 'Proteina')
    if skladnik in humektanty:
        print(kolejnosc + 1, 'Humektant')
    if skladnik in emolienty:
        print(kolejnosc + 1, 'Emolient')
    
print(f'W kosmetyku {kosmetyk} jest: {len(pro_w_kos)} protein, {len(hum_w_kos)} humektantów, {len(emo_w_kos)} emolientów. Kolejność ich występowania: {}')
# Out:
# Wpisz nazwę kosmetyku: on
# Wpisz jego skład: kos, agag, laptop
# 1 Proteina
# 3 Emolient
# W kosmetyku on jest: 1 protein, 0 humektantów, 1 emolientów. Kolejność ich występowania: []

# %%
kosmetyk = input(str('Wpisz nazwę kosmetyku: '))
sklad = input(str('Wpisz jego skład: '))

lista_sklad = sklad.split(', ')

proteiny = ['collagen', 'elastine', 'keratin', 'sericin', 'silk', 'peptide', 'tripeptide', 'amino acids', 'yeast', 'gelatin', 'caprae lac exract', 'albumen', 'casein']
humektanty = ['sodium hyaluronate', 'aloe barbadensis leaf juice', 'aloe barbadensis leaf extract', 'aloe vera', 'panthenol', 'mel', 'glycerin', 'vegetable glycerin', 'lecithin', 'lacid acid', 'allantoin', 'niacynamide', 'propylene glycol', 'butylene glycol', 'algae extract', 'betaine', 'dipotassium', 'dipotassium glycyrrhizate extract', 'fructose', 'honey', 'hyaluronic acid', 'mannitol', 'sucrose', 'sodium hyaluronate', 'sodium pca', 'sorbitol', 'trehalose']
emolienty = ['cetearyl alcohol', 'decyl alcohol', 'misystyl alcohol', 'stearyl alcohol', 'cetyl alcohol', 'octylodecanol', 'paraffinum liquidum', 'paraffin', 'synthetic wax', 'vaseline', 'petroleum', 'ceresin', 'polyisobutane', 'cera alba', 'lanolin', 'cyclomethicone', 'hexamethyldisiloxane', 'dimethicone', 'dimethiconol', 'amodimethicone', 'cyclopentasiloxane']
silikony = ['cyclomethicone', 'hexamethyldisiloxane', 'dimethicone', 'dimethiconol', 'amodimethicone', 'cyclopentasiloxane']
silnedetergenty = ['sodium laureth sulfate', 'sodium lauryl sulfate', 'sodium coco sarcosinate', 'sodium lauryl sulfoacetate', 'sodium myreth sulfate', 'sodium coco-sulfate', 'alkylbenzene sulfonates', 'ammonium laureth sulfate', 'ammonium lauryl sulfate', 'dioctyl sodium sulfosuccinate', 'tea-dodecylbenzenesulfonate', 'ethyl peg-15 cocamine sulfate', 'cocamide dea', 'sodium laureth-5 carboxylate']

pro_w_kos = []
hum_w_kos = []
emo_w_kos = []
inne_w_kos = []
sili_w_kos = []
sil_det = []
    
print(f'\nKolejność ich występowania: ')

for skladnik in lista_sklad:
    print(skladnik)
    
    if skladnik.lower() in proteiny:
        print(f'[P] {skladnik}')
        pro_w_kos.append(skladnik)
    if skladnik.lower() in humektanty:
        print(f'[H] {skladnik}')
        hum_w_kos.append(skladnik)
    if skladnik.lower() in emolienty:
        print(f'[E] {skladnik}')
        emo_w_kos.append(skladnik)
    if skladnik.lower() in silikony:
        print(f'[SILIKON] {skladnik}')
        sili_w_kos.append(skladnik)
    if skladnik.lower() in silnedetergenty:
        print(f'[SILNY DETERGENT] {skladnik}')
        sil_det.append(skladnik)
    if skladnik.lower() not in proteiny + humektanty + emolienty + silnedetergenty:
        if ('oil' or 'butter') in skladnik.lower():
            print(f'[E] {skladnik}')
            emo_w_kos.append(skladnik)
        elif ('protein' or 'hydrolyzed') in skladnik.lower():
            print(f'[P] {skladnik}')
            pro_w_kos.append(skladnik)
        elif ('extract' or 'water' or 'eau' or 'urea' or 'aqua') in skladnik.lower():
            print(f'[H] {skladnik}')
            hum_w_kos.append(skladnik)
        else:
            inne_w_kos.append(skladnik)
            print(f'[X] {skladnik}')

print(f'\nPodsumowanie: ')
print(f'kosmetyk: {kosmetyk}')
print(f'proteiny: {len(pro_w_kos)}') 
print(f'humektanty: {len(hum_w_kos)}')
print(f'emolienty: {len(emo_w_kos)}')
print(f'inne składniki: {len(inne_w_kos) + len(sil_det)}')

# %%
def czy_humektant(skladnik):
    
    sprawdzany_skladnik = skladnik.lower()
    
    humektanty = ['sodium hyaluronate', 'aloe barbadensis leaf juice', 'aloe barbadensis leaf extract', 'aloe vera', 'panthenol', 'mel', 'glycerin', 'lecithin', 'lacid acid', 'allantoin', 'niacynamide', 'propylene glycol', 'butylene glycol', 'algae extract', 'betaine', 'dipotassium', 'dipotassium glycyrrhizate extract', 'fructose', 'honey', 'hyaluronic acid', 'mannitol', 'sucrose', 'sodium hyaluronate', 'sodium pca', 'sorbitol', 'trehalose']
    frazy_humektantowe = ["aqua", "water", 'extract', 'urea', 'eau']
    
    if sprawdzany_skladnik in humektanty:
        return True
    
    for fraza in frazy_humektantowe:
        if fraza in sprawdzany_skladnik:
            return True
    
    return False

print(czy_humektant('oko'))
# Out:
# False

# %%
def czy_proteina(skladnik):
    
    sprawdzany_skladnik = skladnik.lower()
    
    proteiny = ['collagen', 'elastine', 'keratin', 'sericin', 'silk', 'peptide', 'tripeptide', 'amino acids', 'yeast', 'gelatin', 'caprae lac exract', 'albumen', 'casein']
    frazy_proteinowe = ['protein', 'hydrolyzed']
    
    if sprawdzany_skladnik in proteiny:
        return True
    
    for fraza in frazy_proteinowe:
        if fraza in sprawdzany_skladnik:
            return True
    
    return False

print(czy_proteina('silk protein'))
# Out:
# True

# %%
def czy_emolient(skladnik):
    
    sprawdzany_skladnik = skladnik.lower()
    
    emolienty = ['cetearyl alcohol', 'decyl alcohol', 'misystyl alcohol', 'stearyl alcohol', 'cetyl alcohol', 'octylodecanol', 'paraffinum liquidum', 'paraffin', 'synthetic wax', 'vaseline', 'petroleum', 'ceresin', 'polyisobutane', 'cera alba', 'lanolin', 'cyclomethicone', 'hexamethyldisiloxane', 'dimethicone', 'dimethiconol', 'amodimethicone', 'cyclopentasiloxane']
    frazy_emolientowe = ['oil', 'butter']
    
    if sprawdzany_skladnik in emolienty:
        return True
    
    for fraza in frazy_emolientowe:
        if fraza in sprawdzany_skladnik:
            return True
    
    return False

print(czy_emolient(''))
# Out:
# True

# %%
def czy_silikon(skladnik):
    
    sprawdzany_skladnik = skladnik.lower()
    
    silikony = ['cyclomethicone', 'hexamethyldisiloxane', 'dimethicone', 'dimethiconol', 'amodimethicone', 'cyclopentasiloxane']
    
    if sprawdzany_skladnik in silikony:
        return True
    
    return False

print(czy_silikon('cyclomethicone'))
# Out:
# True

# %%
def czy_silnydetergent(skladnik):
    
    sprawdzany_skladnik = skladnik.lower()
    
    silnedetergenty = ['sodium laureth sulfate', 'sodium lauryl sulfate', 'sodium coco sarcosinate', 'sodium lauryl sulfoacetate', 'sodium myreth sulfate', 'sodium coco-sulfate', 'alkylbenzene sulfonates', 'ammonium laureth sulfate', 'ammonium lauryl sulfate', 'dioctyl sodium sulfosuccinate', 'tea-dodecylbenzenesulfonate', 'ethyl peg-15 cocamine sulfate', 'cocamide dea', 'sodium laureth-5 carboxylate']
    
    if sprawdzany_skladnik in silnedetergenty:
        return True
    
    return False

print(czy_silnydetergent('cyclomethicone'))
# Out:
# False

# %%
def filtrowanko(sklad):
    
    dozwolone_znaki = "AĄBCĆDEĘFGHIJKLŁMNŃOÓPRSŚTUWYZŹŻaąbcćdeęfghijklłmnńoóprsśtuwyzźż01234567890-/,. "
    
    przefiltrowany_sklad = ''
    
    
    for znak in sklad:
        if znak in dozwolone_znaki:
            przefiltrowany_sklad += znak
        
    tablica_ze_skladem = przefiltrowany_sklad.split(", ")
    
    return tablica_ze_skladem

# %%
def filtrowanko(sklad):
    
    dozwolone_znaki = "XxQqVvAĄBCĆDEĘFGHIJKLŁMNŃOÓPRSŚTUWYZŹŻaąbcćdeęfghijklłmnńoóprsśtuwyzźż01234567890-/,. "
    
    przefiltrowany_sklad = ''
    
    
    for znak in sklad.lower():
        if znak in dozwolone_znaki:
            przefiltrowany_sklad += znak
        
    tablica_ze_skladem = przefiltrowany_sklad.split(", ")
    
    return tablica_ze_skladem

def czy_humektant(skladnik):
    
    sprawdzany_skladnik = skladnik.lower()
    
    humektanty = ['lactic acid', 'vegetable glycerin', 'sodium hyaluronate', 'aloe barbadensis leaf juice', 'aloe barbadensis leaf extract', 'aloe vera', 'panthenol', 'mel', 'glycerin', 'lecithin', 'lacid acid', 'allantoin', 'niacynamide', 'propylene glycol', 'butylene glycol', 'algae extract', 'betaine', 'dipotassium', 'dipotassium glycyrrhizate extract', 'fructose', 'honey', 'hyaluronic acid', 'mannitol', 'sucrose', 'sodium hyaluronate', 'sodium pca', 'sorbitol', 'trehalose']
    frazy_humektantowe = ["aqua", "water", 'extract', 'urea', 'eau', 'glycerin']
    
    if sprawdzany_skladnik in humektanty:
        return True
    
    for fraza in frazy_humektantowe:
        if fraza in sprawdzany_skladnik:
            return True
    
    return False

def czy_proteina(skladnik):
    
    sprawdzany_skladnik = skladnik.lower()
    
    proteiny = ['collagen', 'elastine', 'keratin', 'sericin', 'silk', 'peptide', 'tripeptide', 'amino acids', 'yeast', 'gelatin', 'caprae lac exract', 'albumen', 'casein']
    frazy_proteinowe = ['protein', 'hydrolyzed']
    
    if sprawdzany_skladnik in proteiny:
        return True
    
    for fraza in frazy_proteinowe:
        if fraza in sprawdzany_skladnik:
            return True
    
    return False


def czy_emolient(skladnik):
    
    sprawdzany_skladnik = skladnik.lower()
    
    emolienty = ['cetearyl alcohol', 'decyl alcohol', 'misystyl alcohol', 'stearyl alcohol', 'cetyl alcohol', 'octylodecanol', 'paraffinum liquidum', 'paraffin', 'synthetic wax', 'vaseline', 'petroleum', 'ceresin', 'polyisobutane', 'cera alba', 'lanolin', 'cyclomethicone', 'hexamethyldisiloxane', 'dimethicone', 'dimethiconol', 'amodimethicone', 'cyclopentasiloxane']
    frazy_emolientowe = ['oil', 'butter', 'mel', 'honey']
    
    if sprawdzany_skladnik in emolienty:
        return True
    
    for fraza in frazy_emolientowe:
        if fraza in sprawdzany_skladnik:
            return True
    
    return False

def czy_silikon(skladnik):
    
    sprawdzany_skladnik = skladnik.lower()
    
    silikony = ['cyclomethicone', 'hexamethyldisiloxane', 'dimethiconol', 'amodimethicone', 'cyclopentasiloxane']
    frazy_silikonowe = ['dimethicone']
    
    if sprawdzany_skladnik in silikony:
        return True
    
    for fraza in frazy_silikonowe:
        if fraza in sprawdzany_skladnik:
            return True
        
    return False

def czy_silnydetergent(skladnik):
    
    sprawdzany_skladnik = skladnik.lower()
    
    silnedetergenty = ['ammonium lauryl sulfate', 'sodium laureth sulfate', 'sodium lauryl sulfate', 'sodium coco sarcosinate', 'sodium lauryl sulfoacetate', 'sodium myreth sulfate', 'sodium coco-sulfate', 'alkylbenzene sulfonates', 'ammonium laureth sulfate', 'ammonium lauryl sulfate', 'dioctyl sodium sulfosuccinate', 'tea-dodecylbenzenesulfonate', 'ethyl peg-15 cocamine sulfate', 'cocamide dea', 'sodium laureth-5 carboxylate']
    frazy_detergentowe = ['sodium laureth', 'sodium lauryl']
    
    if sprawdzany_skladnik in silnedetergenty:
        return True
    
    for fraza in frazy_detergentowe:
        if fraza in sprawdzany_skladnik:
            return True
    
    return False

def czy_inny_skladnik(skladnik):
    
    if czy_humektant(skladnik):
        return False
    if czy_emolient(skladnik):
        return False
    if czy_proteina(skladnik):
        return False
    if czy_silikon(skladnik):
        return False
    if czy_silnydetergent(skladnik):
        return False  
        
    return True


kosmetyk = input(str('Wpisz nazwę kosmetyku: '))
sklad = input(str('Wpisz jego skład: '))

lista_sklad = filtrowanko(sklad)

pro_w_kos = []
hum_w_kos = []
emo_w_kos = []
inne_w_kos = []
sili_w_kos = []
sil_det = []
    
print(f'\nKolejność ich występowania: ')

for skladnik in lista_sklad:
    if czy_proteina(skladnik):
        print(f'[P] {skladnik}')
        pro_w_kos.append(skladnik)
    if czy_humektant(skladnik):
        print(f'[H] {skladnik}')
        hum_w_kos.append(skladnik)
    if czy_emolient(skladnik):
        print(f'[E] {skladnik}')
        emo_w_kos.append(skladnik)
    if czy_silikon(skladnik):
        print(f'[SILIKON] {skladnik}')
        sili_w_kos.append(skladnik)
    if czy_silnydetergent(skladnik):
        print(f'[SILNY DETERGENT] {skladnik}')
        sil_det.append(skladnik)
    if czy_inny_skladnik(skladnik):
        inne_w_kos.append(skladnik)
        print(f'[X] {skladnik}')

print(f'\nPodsumowanie: ')
print(f'kosmetyk: {kosmetyk}')
print(f'proteiny: {len(pro_w_kos)}') 
print(f'humektanty: {len(hum_w_kos)}')
print(f'emolienty: {len(emo_w_kos)}')
print(f'inne składniki: {len(inne_w_kos) + len(sil_det)}')
# Out:
# Wpisz nazwę kosmetyku: dhf
# Wpisz jego skład: Aqua, Silicone Quaternium-18, Pisum Sativum Peptide, Trideceth-6, Stearamidopropyl Dimethylamine, Polysorbate 20, Parfum, Sodium Benzoate, Lactic Acid, Trideceth-12, Phenoxyethanol, Leuconostoc/Radish Root Ferment Filtrate, Limonene, Linalool
#
# Kolejność ich występowania:
# [H] aqua
# [X] silicone quaternium-18
# [X] pisum sativum peptide
# [X] trideceth-6
# [X] stearamidopropyl dimethylamine
# [X] polysorbate 20
# [X] parfum
# [X] sodium benzoate
# [H] lactic acid
# [X] trideceth-12
# [X] phenoxyethanol
# [X] leuconostoc/radish root ferment filtrate
# [X] limonene
# [X] linalool
#
# Podsumowanie:
# kosmetyk: dhf
# proteiny: 0
# humektanty: 2
# emolienty: 0
# inne składniki: 12

# %%
# jeżeli coś jest emolientem i silikonem, drukuje się dwa razy
